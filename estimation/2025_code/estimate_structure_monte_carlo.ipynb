# %% [markdown]
# # Structural Estimation: Monte Carlo

# %%
using Pkg
Pkg.activate(".")
#for pkg in ["BlackBoxOptim", "Cubature", "Distributions", "Integrals", "Roots", "PrettyTables", "JLD", "StatProfilerHTML"] # 
#    Pkg.add(pkg)
#end

Pkg.instantiate()

using Base.Threads, BlackBoxOptim, Cubature, Dates, Distributions, Integrals, Random, Roots, PrettyTables, JLD
# Out:
#   Activating project at `C:\Users\jbrig\Documents\research\mapinator_2024\notes\estimation_of_tau`

# %%
estimated_parameters = load("estimated_parameters_collapse_sinks_new.jld")
# Out:
# Dict{String, Any} with 9 entries:
#   "sol_2"           => [2.48187, 0.476956, 0.429753, -3.75801, 0.358705, 0.2595…
#   "estimated_α"     => [0.1029, 0.140406, 0.173084, 0.0882224, 0.0520296]
#   "estimated_n_val" => 25890.1
#   "estimated_τ"     => 0.556643
#   "k"               => 4
#   "estimated_v_rel" => [0.512286, 0.544467, 0.734376]
#   "estimated_γ"     => [0.184859, 0.252238, 0.310943, 0.15849, 0.0934703]
#   "K"               => 7
#   "m_t_values"      => Any[2664, 3635, 4481, 2284, 1347]

# %%
estimated_sol_2 = estimated_parameters["sol_2"]
estimated_v_rel = estimated_parameters["estimated_v_rel"]
estimated_α = estimated_parameters["estimated_α"]
estimated_τ = estimated_parameters["estimated_τ"]
k = estimated_parameters["k"]
K = estimated_parameters["K"]
m_t_values = estimated_parameters["m_t_values"]
estimated_m_val = sum(m_t_values)
estimated_n_val = (estimated_m_val / estimated_τ) + 1
estimated_m_val
# Out:
# 14411

# %%
estimated_γ = estimated_parameters["estimated_γ"]
# Out:
# 5-element Vector{Float64}:
#  0.1848587884255083
#  0.25223787384636737
#  0.31094302963014364
#  0.15849004232877664
#  0.09347026576920409

# %%
# define p_vec as e.g.
# [v2/v1 v3/v2 v4/v3 α1 α2 α3 α4 mu1 mu2 mu3 mu4 mus sg1 sg2 sg3 sg4 sgs]

function q_prob(t, v_rel, mkt_balance_ratio, gamma, k)
    numerator = prod([v_rel[s] for s in t:k-1])
    denominator = exp(1 / mkt_balance_ratio) * prod([((v_rel[s])^(sum(gamma[1:s]))) for s in 1:k-1])
    return numerator / denominator
end

function F(x, ρ, normals, K)
    sum_base = 0.0
    for i in 1:K
        sum_base += ρ[i] * cdf(normals[i], x)
    end
    return sum_base
end

function f_integrand(integrals, x, p) 
    base_exp = exp(F(x, p.ρ, p.normals, p.K) / sum(p.α[1:p.s]))
    for i in 1:p.K
        integrals[i] = base_exp * pdf(p.normals[i], x)
    end
end

function get_integrals(x_vec, ρ, normals, α, k, K)
    # Fx_vec = [F(x0)=1, F(x1), F(x2), F(x3), ..., F(xk-1)]
    # x_vec = [x0 = 1, x1, x2, x3, ..., xk = 0]
    # x_vec[s] = x_{s-1}, so the limits of integration are and must be offset by 1 below
    all_integrals = zeros(K, k)
    for s in 1:k
        # https://docs.sciml.ai/Integrals/stable/basics/SampledIntegralProblem/ might be faster
        # if f_integrand(x) can be vectorized/sped up
        prob = IntegralProblem(IntegralFunction(f_integrand, zeros(K)), (x_vec[s+1], x_vec[s]), (; s, ρ, normals, α, K))
        sol = solve(prob, CubatureJLh(); reltol = 1e-3, abstol = 1e-3)
        integrals_result = sol.u
        # NOTE: result may be inf if alpha_1 is too small
        # NOTE: some parameter values for μ and σ may cause the cdf F_i to be NaN
        for i in 1:K 
            all_integrals[i, s] = integrals_result[i]
        end
    end
    return all_integrals
end      

function q(i, t, all_integrals, Fx_vec, α, v_rel, k)
    return α[t] * sum([(1/sum(α[1:s])) * prod([v_rel[j] for j in t:(s-1)]) * exp(-Fx_vec[s] / sum(α[1:s])) * all_integrals[i, s] for s in t:k])
end

function Fx(t, α, v_rel)
    return 1 - sum([-log(v_rel[j])*sum(α[1:j]) for j in 1:t])
end

function pi(t, α)
    return α[t] / sum(α[1:t])
end

function ρ_q(t, α, v_rel, k)
    Fx_km1 = Fx(k-1, α, v_rel)
    if Fx_km1 <= 0
        return -1
    end
    last_term = prod([v_rel[j] for j in t:(k-1)]) * (1 - exp((0 - Fx_km1) / sum(α[1:k])))
    return α[t] * (sum([prod([v_rel[j] for j in t:(s-1)]) * (1 - v_rel[s]) for s in t:(k-1)]) + last_term)
end
# Out:
# ρ_q (generic function with 1 method)

# %%
function estimate_parameters_stage_1(p_vec, placements, γ, m_val, k)
    v_rel = p_vec[1:k-1]
    τ = p_vec[k]
    α = τ * γ

    n_val = (m_val / τ) + 1

    objective = 0.0

    ρ_q_t = zeros(k)
    for t in 1:k
        prob = ρ_q(t, α, v_rel, k)
        if prob < 0
            return Inf
        end
        ρ_q_t[t] = prob
    end

    for t in 1:k
        prob = ρ_q_t[t]
        expectation = n_val * prob
        objective += ((sum(placements[:, t]) - expectation) ^ 2) / expectation
    end
    
    return objective
end
# Out:
# estimate_parameters_stage_1 (generic function with 1 method)

# %%
function estimate_likelihood_2(p_vec, v_rel, α, placements, k, K, counter)   
    μ = p_vec[1:K]
    σ = p_vec[K+1:2K]
    ρ_vec = p_vec[2K+1:3K]
    ρ = ρ_vec / sum(ρ_vec)

    ## compute the cutoffs x and the CDF values F(x)
    normals = [truncated(Normal(μ[i], σ[i]), 0, 1) for i in 1:K]

    Fx_vec = ones(k) # sets F(x0) = 1 by default; Fx_vec = [F(x0)=1, F(x1), F(x2), F(x3), ..., F(xk-1)]
    x_vec = ones(k+1) # x_vec = [x0 = 1, x1, x2, x3, ..., xk = 0]
    x_vec[k+1] = 0.0
    for t in 1:k-1
        Fx_vec_candidate = Fx(t, α, v_rel)
        if Fx_vec_candidate <= 0.0 # TODO: if this case occurs, can we speed up q()?
            Fx_vec[t+1:k] .= 0.0
            x_vec[t+1:k] .= 0.0
            break
        end
        Fx_vec[t+1] = Fx_vec_candidate
        # there is no simple closed-form for F^{-1}(x) so this numerically computes x1, x2, x3
        x_vec[t+1] = find_zero(x -> F(x, ρ, normals, K) - Fx_vec[t+1], 0.5) 
    end 

    ρ_q_it = zeros(K, k)
    all_integrals = get_integrals(x_vec, ρ, normals, α, k, K)
    for i in 1:K, t in 1:k
        prob = q(i, t, all_integrals, Fx_vec, α, v_rel, k)
        ρ_q_it[i, t] = ρ[i] * prob
    end

    normalizer = sum(ρ_q_it)
    likelihood = 0.0
    for i in 1:K, t in 1:k
        likelihood += placements[i, t] * log(ρ_q_it[i, t] / normalizer)
    end

    counter[1] += 1
    #if isnan(-likelihood) || isinf(-likelihood)
    #    println(all_integrals)
    #end
    return -likelihood
end
# Out:
# estimate_likelihood_2 (generic function with 1 method)

# %%
function simulate_market(p_vec, v_rel, α, k, K, n_val, m_t)
    μ = p_vec[1:K]
    σ = p_vec[K+1:2K]
    ρ_vec = p_vec[2K+1:3K]
    ρ = ρ_vec / sum(ρ_vec)

    n_i = Int.(round.(n_val * ρ))

    ## compute the cutoffs x and the CDF values F(x)
    normals = [truncated(Normal(μ[i], σ[i]), 0, 1) for i in 1:K]

    Fx_vec = ones(k) # sets F(x0) = 1 by default; Fx_vec = [F(x0)=1, F(x1), F(x2), F(x3), ..., F(xk-1)]
    x_vec = ones(k+1) # x_vec = [x0 = 1, x1, x2, x3, ..., xk = 0]
    x_vec[k+1] = 0.0
    for t in 1:k-1
        Fx_vec_candidate = Fx(t, α, v_rel)
        if Fx_vec_candidate <= 0.0 # TODO: if this case occurs, can we speed up q()?
            Fx_vec[t+1:k] .= 0.0
            x_vec[t+1:k] .= 0.0
            break
        end
        Fx_vec[t+1] = Fx_vec_candidate
        # there is no simple closed-form for F^{-1}(x) so this numerically computes x1, x2, x3
        x_vec[t+1] = find_zero(x -> F(x, ρ, normals, K) - Fx_vec[t+1], 0.5) 
    end 

    graduate_offers = []
    graduate_hiring_tiers = []
    for t in 1:k
        push!(graduate_offers, -1 * ones(m_t[t]))
        push!(graduate_hiring_tiers, -1 * ones(Int, m_t[t]))
    end
    
    for i in 1:K
        # draw wages for every department in every tier/sink
        wages = rand(normals[i], n_i[i])
        for wage in wages
            # iterate over the cutoffs
            for t in 1:k
                if wage < x_vec[t] && wage >= x_vec[t+1]
                    # determine which tier to make the offer to
                    π_j = Categorical([α[j] / sum(α[1:t]) for j in 1:t])
                    offer_tier = rand(π_j)
                    # determine which graduate within the tier to make the offer to
                    selected_graduate = rand(1:m_t[offer_tier])
                    # check for collision
                    if graduate_offers[offer_tier][selected_graduate] == -1 # no offer made to this graduate yet
                        graduate_offers[offer_tier][selected_graduate] = wage
                        graduate_hiring_tiers[offer_tier][selected_graduate] = i
                    else
                        if graduate_offers[offer_tier][selected_graduate] < wage # this offer better than existing offer
                            graduate_offers[offer_tier][selected_graduate] = wage
                            graduate_hiring_tiers[offer_tier][selected_graduate] = i
                        end
                    end 
                    break
                end
            end
        end
    end
    
    simulated_placements_matrix = zeros(Int, K, k)
    unmatched_graduates = zeros(Int, k)
    for t in 1:k
        for graduate in 1:m_t[t]
            if graduate_offers[t][graduate] == -1 # unmatched
                unmatched_graduates[t] += 1
            else # matched
                simulated_placements_matrix[graduate_hiring_tiers[t][graduate], t] += 1
            end
        end
    end

    return simulated_placements_matrix, unmatched_graduates
end
# Out:
# simulate_market (generic function with 1 method)

# %%
NUM_BOOTSTRAP_ROUNDS = 1000
NUM_ESTIMATIONS_PER_ROUND = 5

# upper/lower bound on v_rel
upper_1 = [1.0 for _ in 1:k-1]
lower_1 = [0.0 for _ in 1:k-1]

# upper/lower bound on τ
append!(upper_1, [10.0 for _ in 1:1])
append!(lower_1, [0.25 for _ in 1:1])

search_range_1 = [(lower_1[i], upper_1[i]) for i in eachindex(upper_1)]

# upper/lower bound on the mu parameter of truncated normal
upper_2 = [4.0 for _ in 1:K]
lower_2 = [-4.0 for _ in 1:K]

# upper/lower bound on the sigma parameter of truncated normal
append!(upper_2, [10.0 for _ in 1:K])
append!(lower_2, [0.12 for _ in 1:K])

# upper/lower bound on values proportional to ρ_i
append!(upper_2, [1.0 for _ in 1:K])
append!(lower_2, [0.0 for _ in 1:K])

search_range_2 = [(lower_2[i], upper_2[i]) for i in eachindex(upper_2)]

Random.seed!(0)

bootstrap_placements_output = zeros(Int, NUM_BOOTSTRAP_ROUNDS, K, k)
bootstrap_unmatched_output = zeros(Int, NUM_BOOTSTRAP_ROUNDS, k)
bootstrap_stage_1_estimates_output = zeros(NUM_BOOTSTRAP_ROUNDS, length(upper_1))
bootstrap_stage_2_estimates_output = zeros(NUM_BOOTSTRAP_ROUNDS, length(upper_2))
bootstrap_stage_1_fitness_output = zeros(NUM_BOOTSTRAP_ROUNDS)
bootstrap_stage_2_fitness_output = zeros(NUM_BOOTSTRAP_ROUNDS)
bootstrap_counter_output = zeros(Int, NUM_BOOTSTRAP_ROUNDS)

max_evals_stage_1 = 1000000
max_evals_stage_2 = 100000

Threads.@threads for bootstrap_round in 1:NUM_BOOTSTRAP_ROUNDS
    println("Starting round $bootstrap_round")
    start_time = Dates.datetime2unix(Dates.now())

    bootstrap_placements, bootstrap_unmatched = simulate_market(estimated_sol_2, estimated_v_rel, estimated_α, k, K, estimated_n_val, m_t_values)
    
    bootstrap_placements_output[bootstrap_round, :, :] = bootstrap_placements[:, :]
    bootstrap_unmatched_output[bootstrap_round, :] = bootstrap_unmatched[:]

    sol_res_1 = bboptimize(p -> estimate_parameters_stage_1(p, bootstrap_placements, estimated_γ, estimated_m_val, k), SearchRange = search_range_1, MaxFuncEvals = max_evals_stage_1, TraceMode = :silent) 
    # MaxTime = 60.0, MaxFuncEvals = 500000,
    sol_1 = best_candidate(sol_res_1)
    sol_1_fitness = best_fitness(sol_res_1)

    bootstrap_v_rel = sol_1[1:k-1]
    bootstrap_τ = sol_1[k]
    bootstrap_α = bootstrap_τ * estimated_γ
    
    bootstrap_stage_1_estimates_output[bootstrap_round, :] = sol_1[:]
    bootstrap_stage_1_fitness_output[bootstrap_round] = sol_1_fitness

    println("  round $bootstrap_round s1 best estimate: fitness $sol_1_fitness")

    best_fitness_val = Inf
    best_counter = 0
    best_sol = nothing
    stage_2_start_time = Dates.datetime2unix(Dates.now())
    for bootstrap_round_estimation in 1:NUM_ESTIMATIONS_PER_ROUND
        counter = [0]
        sol_res_2 = bboptimize(p -> estimate_likelihood_2(p, bootstrap_v_rel, bootstrap_α, bootstrap_placements, k, K, counter), SearchRange = search_range_2, MaxFuncEvals = max_evals_stage_2, TraceMode = :silent) 
        # MaxTime = 60.0, MaxFuncEvals = 500000,
        sol_2 = best_candidate(sol_res_2)
        sol_2_fitness = best_fitness(sol_res_2)
        if sol_2_fitness < best_fitness_val
            time_so_far = Dates.datetime2unix(Dates.now())
            println("    improvement in round $bootstrap_round est. $bootstrap_round_estimation: $sol_2_fitness (counter = $(counter[1])) < $best_fitness_val (counter = $best_counter); ($(time_so_far - start_time)s total)")
            best_fitness_val = sol_2_fitness
            best_counter = counter[1]
            best_sol = sol_2
        end
    end
    stage_2_end_time = Dates.datetime2unix(Dates.now())
    bootstrap_stage_2_estimates_output[bootstrap_round, :] = best_sol[:]
    bootstrap_stage_2_fitness_output[bootstrap_round] = best_fitness_val
    bootstrap_counter_output[bootstrap_round] = best_counter
    end_time = Dates.datetime2unix(Dates.now())
    println("round $bootstrap_round s2 best estimate: fitness $best_fitness_val after $best_counter iterations (runtime: $(end_time - start_time)s, avg s2 runtime: $((stage_2_end_time - stage_2_start_time)/NUM_ESTIMATIONS_PER_ROUND)s)")
end

save("monte_carlo_structure_results_collapse_sinks_1000_new.jld", "placements", bootstrap_placements_output, "unmatched", bootstrap_unmatched_output, "stage_1_estimates", bootstrap_stage_1_estimates_output, "stage_2_estimates", bootstrap_stage_2_estimates_output, "stage_1_fitness", bootstrap_stage_1_fitness_output, "stage_2_fitness", bootstrap_stage_2_fitness_output, "counter", bootstrap_counter_output, "k", k, "K", K, "max_evals_stage_1", max_evals_stage_1, "max_evals_stage_2", max_evals_stage_2, "bootstrap_rounds", NUM_BOOTSTRAP_ROUNDS, "estimations_per_round", NUM_ESTIMATIONS_PER_ROUND);
# Out:
# Starting round 425
# Starting round 54
# Starting round 897
# Starting round 949
# Starting round 372
# Starting round 107
# Starting round 689
# Starting round 531
# Starting round 478
# Starting round 1
# Starting round 584
# Starting round 741
# Starting round 793
# Starting round 319
# Starting round 637
# Starting round 845
# Starting round 266
# Starting round 160
# Starting round 213
#   round 107 s1 best estimate: fitness 0.0
#   round 425 s1 best estimate: fitness 0.0
#   round 793 s1 best estimate: fitness 0.0
#   round 1 s1 best estimate: fitness 0.0
#   round 54 s1 best estimate: fitness 0.0
#   round 949 s1 best estimate: fitness 0.0
#   round 584 s1 best estimate: fitness 0.0
#   round 213 s1 best estimate: fitness 0.0
#   round 897 s1 best estimate: fitness 0.0
#   round 845 s1 best estimate: fitness 3.1485254740903914e-29
#   round 689 s1 best estimate: fitness 0.0
#   round 160 s1 best estimate: fitness 3.1143848364195316e-29
#   round 372 s1 best estimate: fitness 0.0
#   round 478 s1 best estimate: fitness 0.0
#   round 531 s1 best estimate: fitness 0.0
#   round 637 s1 best estimate: fitness 0.0
#   round 266 s1 best estimate: fitness 0.0
#   round 319 s1 best estimate: fitness 0.0
#   round 741 s1 best estimate: fitness 0.0
#     improvement in round 107 est. 1: 33044.076824549855 (counter = 100002) < Inf (counter = 0); (37.2739999294281s total)
#     improvement in round 793 est. 1: 33011.749599325805 (counter = 100002) < Inf (counter = 0); (37.323999881744385s total)
#     improvement in round 1 est. 1: 32822.245018186404 (counter = 100002) < Inf (counter = 0); (38.710999965667725s total)
#     improvement in round 425 est. 1: 32765.653832117307 (counter = 100002) < Inf (counter = 0); (39.14399981498718s total)
#     improvement in round 584 est. 1: 33160.59164099077 (counter = 100002) < Inf (counter = 0); (39.585999965667725s total)
#     improvement in round 213 est. 1: 33316.13835135133 (counter = 100002) < Inf (counter = 0); (38.901000022888184s total)
#     improvement in round 319 est. 1: 32902.46719917796 (counter = 100002) < Inf (counter = 0); (39.3970000743866s total)
#     improvement in round 689 est. 1: 32703.129349667724 (counter = 100002) < Inf (counter = 0); (40.66799998283386s total)
#     improvement in round 949 est. 1: 32863.9286904952 (counter = 100002) < Inf (counter = 0); (40.95599985122681s total)
#     improvement in round 160 est. 1: 32854.52655889803 (counter = 100002) < Inf (counter = 0); (39.76300001144409s total)
#     improvement in round 266 est. 1: 32949.341241714676 (counter = 100002) < Inf (counter = 0); (39.9300000667572s total)
#     improvement in round 478 est. 1: 33008.28573359453 (counter = 100002) < Inf (counter = 0); (41.29299998283386s total)
#     improvement in round 897 est. 1: 33072.81415884403 (counter = 100002) < Inf (counter = 0); (41.294999837875366s total)
#     improvement in round 845 est. 1: 32800.69140705325 (counter = 100002) < Inf (counter = 0); (40.26199984550476s total)
#     improvement in round 637 est. 1: 32989.13521626436 (counter = 100002) < Inf (counter = 0); (40.49500012397766s total)
#     improvement in round 372 est. 1: 32965.69171431397 (counter = 100002) < Inf (counter = 0); (41.835999965667725s total)
#     improvement in round 531 est. 1: 32985.06022841378 (counter = 100002) < Inf (counter = 0); (42.056999921798706s total)
#     improvement in round 741 est. 1: 32977.2234908439 (counter = 100002) < Inf (counter = 0); (42.41799998283386s total)
#     improvement in round 54 est. 1: 33004.56515702798 (counter = 100002) < Inf (counter = 0); (45.17199993133545s total)
#     improvement in round 793 est. 2: 33011.68749118521 (counter = 100002) < 33011.749599325805 (counter = 100002); (62.08299994468689s total)
#     improvement in round 425 est. 2: 32765.635887590262 (counter = 100002) < 32765.653832117307 (counter = 100002); (65.63599991798401s total)
#     improvement in round 949 est. 2: 32863.39226888479 (counter = 100002) < 32863.9286904952 (counter = 100002); (65.80799984931946s total)
#     improvement in round 584 est. 2: 33160.51180285857 (counter = 100002) < 33160.59164099077 (counter = 100002); (66.96799993515015s total)
#     improvement in round 845 est. 2: 32799.87158563796 (counter = 100002) < 32800.69140705325 (counter = 100002); (66.1579999923706s total)
#     improvement in round 531 est. 2: 32984.945310513525 (counter = 100002) < 32985.06022841378 (counter = 100002); (67.97899985313416s total)
#     improvement in round 319 est. 2: 32902.123260280365 (counter = 100002) < 32902.46719917796 (counter = 100002); (67.28999996185303s total)
#     improvement in round 741 est. 2: 32977.08817285033 (counter = 100002) < 32977.2234908439 (counter = 100002); (68.61299991607666s total)
#     improvement in round 1 est. 3: 32821.65631001359 (counter = 100002) < 32822.245018186404 (counter = 100002); (90.73699998855591s total)
#     improvement in round 425 est. 3: 32765.480779278816 (counter = 100002) < 32765.635887590262 (counter = 100002); (92.95899987220764s total)
#     improvement in round 213 est. 3: 33316.13509439379 (counter = 100002) < 33316.13835135133 (counter = 100002); (92.33000016212463s total)
#     improvement in round 425 est. 4: 32765.273339245534 (counter = 100002) < 32765.480779278816 (counter = 100002); (119.5329999923706s total)
#     improvement in round 741 est. 4: 32977.00106381225 (counter = 100002) < 32977.08817285033 (counter = 100002); (120.67499995231628s total)
#     improvement in round 213 est. 4: 33316.13120153127 (counter = 100002) < 33316.13509439379 (counter = 100002); (119.3970000743866s total)
#     improvement in round 372 est. 4: 32965.561504106605 (counter = 100002) < 32965.69171431397 (counter = 100002); (121.2279999256134s total)
# round 793 s2 best estimate: fitness 33011.68749118521 after 100002 iterations (runtime: 139.36800003051758s, avg s2 runtime: 25.537400007247925s)
# Starting round 794
#     improvement in round 107 est. 5: 33043.94312683508 (counter = 100002) < 33044.076824549855 (counter = 100002); (142.91100001335144s total)
# round 107 s2 best estimate: fitness 33043.94312683508 after 100002 iterations (runtime: 142.9119999408722s, avg s2 runtime: 26.246000003814697s)
# Starting round 108
# round 1 s2 best estimate: fitness 32821.65631001359 after 100002 iterations (runtime: 144.30099987983704s, avg s2 runtime: 26.51399998664856s)
# Starting round 2
#     improvement in round 531 est. 5: 32984.939062794336 (counter = 100002) < 32984.945310513525 (counter = 100002); (144.8399999141693s total)
# round 531 s2 best estimate: fitness 32984.939062794336 after 100002 iterations (runtime: 144.8399999141693s, avg s2 runtime: 25.416800022125244s)
# Starting round 532
#     improvement in round 845 est. 5: 32799.56489599108 (counter = 100002) < 32799.87158563796 (counter = 100002); (144.23300004005432s total)
# round 845 s2 best estimate: fitness 32799.56489599108 after 100002 iterations (runtime: 144.23300004005432s, avg s2 runtime: 25.677800035476686s)
# Starting round 846
#   round 794 s1 best estimate: fitness 0.0
# round 949 s2 best estimate: fitness 32863.39226888479 after 100002 iterations (runtime: 145.9779999256134s, avg s2 runtime: 26.023400020599365s)
# Starting round 950
#     improvement in round 637 est. 5: 32989.132643456745 (counter = 100002) < 32989.13521626436 (counter = 100002); (144.97399997711182s total)
# round 637 s2 best estimate: fitness 32989.132643456745 after 100002 iterations (runtime: 144.97399997711182s, avg s2 runtime: 25.614799976348877s)
# Starting round 638
#     improvement in round 425 est. 5: 32765.196974328363 (counter = 100002) < 32765.273339245534 (counter = 100002); (146.12599992752075s total)
# round 425 s2 best estimate: fitness 32765.196974328363 after 100002 iterations (runtime: 146.12599992752075s, avg s2 runtime: 26.88880000114441s)
# Starting round 426
# round 689 s2 best estimate: fitness 32703.129349667724 after 100002 iterations (runtime: 146.33699989318848s, avg s2 runtime: 25.78600001335144s)
# Starting round 690
# round 478 s2 best estimate: fitness 33008.28573359453 after 100002 iterations (runtime: 146.3899998664856s, avg s2 runtime: 25.735799980163574s)
# Starting round 479
#     improvement in round 213 est. 5: 33316.127489332044 (counter = 100002) < 33316.13120153127 (counter = 100002); (144.8860001564026s total)
# round 213 s2 best estimate: fitness 33316.127489332044 after 100002 iterations (runtime: 144.8860001564026s, avg s2 runtime: 26.011000013351442s)
# Starting round 214
# round 266 s2 best estimate: fitness 32949.341241714676 after 100002 iterations (runtime: 146.7739999294281s, avg s2 runtime: 25.97039999961853s)
# Starting round 267
# round 741 s2 best estimate: fitness 32977.00106381225 after 100002 iterations (runtime: 148.17199993133545s, avg s2 runtime: 25.879999971389772s)
# Starting round 742
# round 584 s2 best estimate: fitness 33160.51180285857 after 100002 iterations (runtime: 148.31299996376038s, avg s2 runtime: 26.45260000228882s)
# Starting round 585
# round 372 s2 best estimate: fitness 32965.561504106605 after 100002 iterations (runtime: 149.07999992370605s, avg s2 runtime: 26.274200010299683s)
# Starting round 373
# round 897 s2 best estimate: fitness 33072.81415884403 after 100002 iterations (runtime: 149.41799998283386s, avg s2 runtime: 26.566200017929077s)
# Starting round 898
# round 319 s2 best estimate: fitness 32902.123260280365 after 100002 iterations (runtime: 149.1159999370575s, avg s2 runtime: 26.399199962615967s)
# Starting round 320
# round 160 s2 best estimate: fitness 32854.52655889803 after 100002 iterations (runtime: 149.34599995613098s, avg s2 runtime: 26.589400005340575s)
# Starting round 161
#   round 108 s1 best estimate: fitness 3.1106370809003744e-29
#   round 950 s1 best estimate: fitness 3.1389671089595764e-29
#   round 426 s1 best estimate: fitness 0.0
#   round 214 s1 best estimate: fitness 0.0
#   round 532 s1 best estimate: fitness 0.0
#   round 846 s1 best estimate: fitness 0.0
#   round 2 s1 best estimate: fitness 0.0
#   round 638 s1 best estimate: fitness 0.0
#   round 479 s1 best estimate: fitness 0.0
#   round 690 s1 best estimate: fitness 3.1370623959080234e-29
#   round 742 s1 best estimate: fitness 5.818659345477121e-29
#   round 267 s1 best estimate: fitness 0.0
#   round 585 s1 best estimate: fitness 0.0
#   round 373 s1 best estimate: fitness 3.131362100821576e-29
#   round 898 s1 best estimate: fitness 0.0
#   round 320 s1 best estimate: fitness 0.0
#   round 161 s1 best estimate: fitness 0.0
#     improvement in round 794 est. 1: 33138.202861468475 (counter = 100002) < Inf (counter = 0); (39.681999921798706s total)
#     improvement in round 108 est. 1: 33324.46225063043 (counter = 100002) < Inf (counter = 0); (38.24600005149841s total)
#     improvement in round 950 est. 1: 32904.24950114719 (counter = 100002) < Inf (counter = 0); (36.88499999046326s total)
#     improvement in round 214 est. 1: 32915.56105386114 (counter = 100002) < Inf (counter = 0); (37.29199981689453s total)
#     improvement in round 532 est. 1: 32923.57042481458 (counter = 100002) < Inf (counter = 0); (38.91000008583069s total)
#     improvement in round 426 est. 1: 32982.35324245872 (counter = 100002) < Inf (counter = 0); (37.75600004196167s total)
#     improvement in round 846 est. 1: 32872.557216893685 (counter = 100002) < Inf (counter = 0); (38.78500008583069s total)
#     improvement in round 638 est. 1: 32961.50168427777 (counter = 100002) < Inf (counter = 0); (38.138999938964844s total)
#     improvement in round 690 est. 1: 32904.59002941313 (counter = 100002) < Inf (counter = 0); (39.007999897003174s total)
#     improvement in round 2 est. 1: 32951.87234764577 (counter = 100002) < Inf (counter = 0); (41.21900010108948s total)
#     improvement in round 585 est. 1: 32934.85333858531 (counter = 100002) < Inf (counter = 0); (38.00099992752075s total)
#     improvement in round 479 est. 1: 32733.383103658638 (counter = 100002) < Inf (counter = 0); (39.961000204086304s total)
#     improvement in round 742 est. 1: 32858.229478162255 (counter = 100002) < Inf (counter = 0); (38.235000133514404s total)
#     improvement in round 267 est. 1: 32930.37292424794 (counter = 100002) < Inf (counter = 0); (39.19999980926514s total)
#     improvement in round 373 est. 1: 33133.91462091156 (counter = 100002) < Inf (counter = 0); (38.29800009727478s total)
#     improvement in round 898 est. 1: 32695.241174486364 (counter = 100002) < Inf (counter = 0); (38.288999795913696s total)
#     improvement in round 320 est. 1: 32951.54417487388 (counter = 100002) < Inf (counter = 0); (38.06500005722046s total)
#     improvement in round 161 est. 1: 32807.92387771447 (counter = 100002) < Inf (counter = 0); (37.98399996757507s total)
#     improvement in round 794 est. 2: 33135.95351829038 (counter = 100002) < 33138.202861468475 (counter = 100002); (64.72499990463257s total)
#     improvement in round 108 est. 2: 33323.929026394544 (counter = 100002) < 33324.46225063043 (counter = 100002); (62.15700006484985s total)
#     improvement in round 532 est. 2: 32923.5243035438 (counter = 100002) < 32923.57042481458 (counter = 100002); (63.37100005149841s total)
#     improvement in round 426 est. 2: 32982.30426469948 (counter = 100002) < 32982.35324245872 (counter = 100002); (62.34500002861023s total)
#     improvement in round 638 est. 2: 32961.47124255586 (counter = 100002) < 32961.50168427777 (counter = 100002); (62.48699998855591s total)
#     improvement in round 214 est. 2: 32915.55831681147 (counter = 100002) < 32915.56105386114 (counter = 100002); (62.895999908447266s total)
#     improvement in round 846 est. 2: 32872.52155331165 (counter = 100002) < 32872.557216893685 (counter = 100002); (64.14199995994568s total)
#     improvement in round 2 est. 2: 32951.32101125305 (counter = 100002) < 32951.87234764577 (counter = 100002); (65.66300010681152s total)
#     improvement in round 373 est. 2: 33133.88350053315 (counter = 100002) < 33133.91462091156 (counter = 100002); (63.05400013923645s total)
#     improvement in round 161 est. 2: 32806.19750900684 (counter = 100002) < 32807.92387771447 (counter = 100002); (63.59299993515015s total)
#     improvement in round 108 est. 3: 33323.67246905639 (counter = 100002) < 33323.929026394544 (counter = 100002); (85.99399995803833s total)
#     improvement in round 794 est. 3: 33135.57722853178 (counter = 100002) < 33135.95351829038 (counter = 100002); (90.81799983978271s total)
#     improvement in round 214 est. 3: 32915.542846864584 (counter = 100002) < 32915.55831681147 (counter = 100002); (88.06399989128113s total)
#     improvement in round 585 est. 3: 32934.8529778807 (counter = 100002) < 32934.85333858531 (counter = 100002); (88.56599998474121s total)
#     improvement in round 373 est. 3: 33133.85311653988 (counter = 100002) < 33133.88350053315 (counter = 100002); (89.06100010871887s total)
#     improvement in round 898 est. 3: 32695.224041472815 (counter = 100002) < 32695.241174486364 (counter = 100002); (89.10599994659424s total)
#     improvement in round 426 est. 4: 32982.25965568236 (counter = 100002) < 32982.30426469948 (counter = 100002); (112.57500004768372s total)
#     improvement in round 479 est. 4: 32733.38261945913 (counter = 100002) < 32733.383103658638 (counter = 100002); (114.87800002098083s total)
#     improvement in round 373 est. 4: 33133.81063101257 (counter = 100002) < 33133.85311653988 (counter = 100002); (114.9390001296997s total)
#     improvement in round 320 est. 4: 32951.39024903642 (counter = 100002) < 32951.54417487388 (counter = 100002); (114.75100016593933s total)
# round 54 s2 best estimate: fitness 33004.56515702798 after 100002 iterations (runtime: 277.14299988746643s, avg s2 runtime: 52.589599990844725s)
# Starting round 55
# round 108 s2 best estimate: fitness 33323.67246905639 after 100002 iterations (runtime: 135.57399988174438s, avg s2 runtime: 25.385199975967407s)
# Starting round 109
# round 794 s2 best estimate: fitness 33135.57722853178 after 100002 iterations (runtime: 141.6949999332428s, avg s2 runtime: 27.094999980926513s)
# Starting round 795
# round 950 s2 best estimate: fitness 32904.24950114719 after 100002 iterations (runtime: 138.00099992752075s, avg s2 runtime: 26.155399990081786s)
# Starting round 951
#     improvement in round 532 est. 5: 32923.52227455849 (counter = 100002) < 32923.5243035438 (counter = 100002); (139.75999999046326s total)
# round 532 s2 best estimate: fitness 32923.52227455849 after 100002 iterations (runtime: 139.75999999046326s, avg s2 runtime: 25.976000022888183s)
# Starting round 533
# round 426 s2 best estimate: fitness 32982.25965568236 after 100002 iterations (runtime: 138.90100002288818s, avg s2 runtime: 26.348799991607667s)
# Starting round 427
#   round 55 s1 best estimate: fitness 0.0
# round 638 s2 best estimate: fitness 32961.47124255586 after 100002 iterations (runtime: 140.3050000667572s, avg s2 runtime: 26.230399990081786s)
# Starting round 639
#   round 109 s1 best estimate: fitness 0.0
# round 214 s2 best estimate: fitness 32915.542846864584 after 100002 iterations (runtime: 140.0849997997284s, avg s2 runtime: 26.624799966812134s)
# Starting round 215
# round 585 s2 best estimate: fitness 32934.8529778807 after 100002 iterations (runtime: 138.3420000076294s, avg s2 runtime: 25.703599977493287s)
# Starting round 586
# round 267 s2 best estimate: fitness 32930.37292424794 after 100002 iterations (runtime: 138.91799998283386s, avg s2 runtime: 25.761000013351442s)
# Starting round 268
# round 846 s2 best estimate: fitness 32872.52155331165 after 100002 iterations (runtime: 141.82399988174438s, avg s2 runtime: 26.473199987411498s)
# Starting round 847
# round 2 s2 best estimate: fitness 32951.32101125305 after 100002 iterations (runtime: 143.31500005722046s, avg s2 runtime: 26.507999992370607s)
# Starting round 3
#     improvement in round 479 est. 5: 32733.371688278752 (counter = 100002) < 32733.38261945913 (counter = 100002); (141.5860002040863s total)
# round 479 s2 best estimate: fitness 32733.371688278752 after 100002 iterations (runtime: 141.5860002040863s, avg s2 runtime: 26.39079999923706s)
# Starting round 480
# round 742 s2 best estimate: fitness 32858.229478162255 after 100002 iterations (runtime: 140.30200004577637s, avg s2 runtime: 26.128600025177s)
# Starting round 743
# round 690 s2 best estimate: fitness 32904.59002941313 after 100002 iterations (runtime: 142.91599988937378s, avg s2 runtime: 26.61879997253418s)
# Starting round 691
#   round 795 s1 best estimate: fitness 0.0
# round 898 s2 best estimate: fitness 32695.224041472815 after 100002 iterations (runtime: 140.85899996757507s, avg s2 runtime: 26.176200008392335s)
# Starting round 899
# round 373 s2 best estimate: fitness 33133.81063101257 after 100002 iterations (runtime: 142.0829999446869s, avg s2 runtime: 26.380599975585938s)
# Starting round 374
#   round 951 s1 best estimate: fitness 0.0
# round 320 s2 best estimate: fitness 32951.39024903642 after 100002 iterations (runtime: 142.04999995231628s, avg s2 runtime: 26.381399965286256s)
# Starting round 321
# round 161 s2 best estimate: fitness 32806.19750900684 after 100002 iterations (runtime: 142.32399988174438s, avg s2 runtime: 26.471000003814698s)
# Starting round 162
#   round 639 s1 best estimate: fitness 0.0
#   round 533 s1 best estimate: fitness 3.1181416335684093e-29
#   round 427 s1 best estimate: fitness 0.0
#   round 480 s1 best estimate: fitness 0.0
#   round 215 s1 best estimate: fitness 0.0
#   round 586 s1 best estimate: fitness 0.0
#   round 268 s1 best estimate: fitness 0.0
#   round 691 s1 best estimate: fitness 3.0975906701356634e-29
#   round 3 s1 best estimate: fitness 0.0
#   round 847 s1 best estimate: fitness 0.0
#   round 743 s1 best estimate: fitness 0.0
#   round 374 s1 best estimate: fitness 3.10130703566672e-29
#   round 899 s1 best estimate: fitness 0.0
#   round 321 s1 best estimate: fitness 3.123793854052219e-29
#   round 162 s1 best estimate: fitness 5.826856949514142e-29
#     improvement in round 55 est. 1: 32896.96754395899 (counter = 100002) < Inf (counter = 0); (35.69700002670288s total)
#     improvement in round 109 est. 1: 32885.26772848028 (counter = 100002) < Inf (counter = 0); (34.949000120162964s total)
#     improvement in round 795 est. 1: 33039.988024376355 (counter = 100002) < Inf (counter = 0); (35.70900011062622s total)
#     improvement in round 951 est. 1: 32913.00969132496 (counter = 100002) < Inf (counter = 0); (33.12599992752075s total)
#     improvement in round 639 est. 1: 32981.04149679793 (counter = 100002) < Inf (counter = 0); (32.58999991416931s total)
#     improvement in round 533 est. 1: 32968.889536591836 (counter = 100002) < Inf (counter = 0); (34.82299995422363s total)
#     improvement in round 480 est. 1: 32738.76138303436 (counter = 100002) < Inf (counter = 0); (32.204999923706055s total)
#     improvement in round 586 est. 1: 33081.4696699642 (counter = 100002) < Inf (counter = 0); (33.69700002670288s total)
#     improvement in round 215 est. 1: 32820.24854290855 (counter = 100002) < Inf (counter = 0); (34.18500018119812s total)
#     improvement in round 3 est. 1: 32885.799390611646 (counter = 100002) < Inf (counter = 0); (33.30299997329712s total)
#     improvement in round 691 est. 1: 32746.000407943575 (counter = 100002) < Inf (counter = 0); (31.700000047683716s total)
#     improvement in round 427 est. 1: 32984.51226108712 (counter = 100002) < Inf (counter = 0); (36.293999910354614s total)
#     improvement in round 268 est. 1: 32924.04556108109 (counter = 100002) < Inf (counter = 0); (34.45700001716614s total)
#     improvement in round 847 est. 1: 32931.76198220312 (counter = 100002) < Inf (counter = 0); (34.29699993133545s total)
#     improvement in round 374 est. 1: 32959.58260118509 (counter = 100002) < Inf (counter = 0); (31.121999979019165s total)
#     improvement in round 743 est. 1: 32818.23787902363 (counter = 100002) < Inf (counter = 0); (34.08399987220764s total)
#     improvement in round 899 est. 1: 32807.14288010116 (counter = 100002) < Inf (counter = 0); (34.128000020980835s total)
#     improvement in round 162 est. 1: 32841.44404856084 (counter = 100002) < Inf (counter = 0); (33.121999979019165s total)
#     improvement in round 321 est. 1: 32920.176637457516 (counter = 100002) < Inf (counter = 0); (35.16499996185303s total)
#     improvement in round 109 est. 2: 32885.08255873557 (counter = 100002) < 32885.26772848028 (counter = 100002); (59.902000188827515s total)
#     improvement in round 951 est. 2: 32912.994034956806 (counter = 100002) < 32913.00969132496 (counter = 100002); (58.64100003242493s total)
#     improvement in round 639 est. 2: 32981.04133964446 (counter = 100002) < 32981.04149679793 (counter = 100002); (56.700000047683716s total)
#     improvement in round 533 est. 2: 32968.884564134365 (counter = 100002) < 32968.889536591836 (counter = 100002); (60.1949999332428s total)
#     improvement in round 3 est. 2: 32885.796977969636 (counter = 100002) < 32885.799390611646 (counter = 100002); (57.93499994277954s total)
#     improvement in round 847 est. 2: 32931.72186544592 (counter = 100002) < 32931.76198220312 (counter = 100002); (59.21799993515015s total)
#     improvement in round 427 est. 2: 32984.5062210369 (counter = 100002) < 32984.51226108712 (counter = 100002); (61.656999826431274s total)
#     improvement in round 374 est. 2: 32959.108437022376 (counter = 100002) < 32959.58260118509 (counter = 100002); (55.70799994468689s total)
#     improvement in round 743 est. 2: 32818.19429072187 (counter = 100002) < 32818.23787902363 (counter = 100002); (58.550999879837036s total)
#     improvement in round 215 est. 2: 32820.22669818848 (counter = 100002) < 32820.24854290855 (counter = 100002); (60.67500019073486s total)
#     improvement in round 899 est. 2: 32806.82745891385 (counter = 100002) < 32807.14288010116 (counter = 100002); (59.396000146865845s total)
#     improvement in round 162 est. 2: 32841.39626415626 (counter = 100002) < 32841.44404856084 (counter = 100002); (57.68300008773804s total)
#     improvement in round 321 est. 2: 32920.10160771632 (counter = 100002) < 32920.176637457516 (counter = 100002); (60.54099988937378s total)
#     improvement in round 951 est. 3: 32912.94456674263 (counter = 100002) < 32912.994034956806 (counter = 100002); (83.22000002861023s total)
#     improvement in round 3 est. 3: 32885.770340884665 (counter = 100002) < 32885.796977969636 (counter = 100002); (83.47399997711182s total)
#     improvement in round 215 est. 3: 32820.21907187182 (counter = 100002) < 32820.22669818848 (counter = 100002); (85.40500020980835s total)
#     improvement in round 427 est. 3: 32984.50260730124 (counter = 100002) < 32984.5062210369 (counter = 100002); (87.1859998703003s total)
#     improvement in round 162 est. 3: 32841.392130165914 (counter = 100002) < 32841.39626415626 (counter = 100002); (81.76300001144409s total)
#     improvement in round 586 est. 4: 33081.29131886863 (counter = 100002) < 33081.4696699642 (counter = 100002); (106.62199997901917s total)
#     improvement in round 427 est. 4: 32984.50221282555 (counter = 100002) < 32984.50260730124 (counter = 100002); (112.37399983406067s total)
# round 109 s2 best estimate: fitness 32885.08255873557 after 100002 iterations (runtime: 136.9960000514984s, avg s2 runtime: 25.806199979782104s)
# Starting round 110
# round 951 s2 best estimate: fitness 32912.94456674263 after 100002 iterations (runtime: 132.97500014305115s, avg s2 runtime: 24.994400024414062s)
# Starting round 952
# round 795 s2 best estimate: fitness 33039.988024376355 after 100002 iterations (runtime: 136.28999996185303s, avg s2 runtime: 25.50640001296997s)
# Starting round 796
# round 533 s2 best estimate: fitness 32968.884564134365 after 100002 iterations (runtime: 133.08100008964539s, avg s2 runtime: 24.80460000038147s)
# Starting round 534
# round 586 s2 best estimate: fitness 33081.29131886863 after 100002 iterations (runtime: 131.9060001373291s, avg s2 runtime: 24.62400002479553s)
# Starting round 587
# round 847 s2 best estimate: fitness 32931.72186544592 after 100002 iterations (runtime: 131.82499980926514s, avg s2 runtime: 24.48239998817444s)
# Starting round 848
# round 743 s2 best estimate: fitness 32818.19429072187 after 100002 iterations (runtime: 132.10999989509583s, avg s2 runtime: 24.58479995727539s)
# Starting round 744
# round 268 s2 best estimate: fitness 32924.04556108109 after 100002 iterations (runtime: 133.74399995803833s, avg s2 runtime: 24.932600021362305s)
# Starting round 269
# round 480 s2 best estimate: fitness 32738.76138303436 after 100002 iterations (runtime: 133.07599997520447s, avg s2 runtime: 25.217399978637694s)
# Starting round 481
#   round 110 s1 best estimate: fitness 0.0
# round 691 s2 best estimate: fitness 32746.000407943575 after 100002 iterations (runtime: 131.9539999961853s, avg s2 runtime: 25.007800006866454s)
# Starting round 692
# round 215 s2 best estimate: fitness 32820.21907187182 after 100002 iterations (runtime: 134.78200006484985s, avg s2 runtime: 25.180999994277954s)
# Starting round 216
# round 374 s2 best estimate: fitness 32959.108437022376 after 100002 iterations (runtime: 131.12299990653992s, avg s2 runtime: 24.789400005340575s)
# Starting round 375
#     improvement in round 3 est. 5: 32885.7676244839 (counter = 100002) < 32885.770340884665 (counter = 100002); (134.7300000190735s total)
# round 3 s2 best estimate: fitness 32885.7676244839 after 100002 iterations (runtime: 134.73099994659424s, avg s2 runtime: 25.189799976348876s)
# Starting round 4
# round 427 s2 best estimate: fitness 32984.50221282555 after 100002 iterations (runtime: 138.2460000514984s, avg s2 runtime: 25.81100001335144s)
# Starting round 428
# round 162 s2 best estimate: fitness 32841.392130165914 after 100002 iterations (runtime: 132.68300008773804s, avg s2 runtime: 24.864800024032593s)
# Starting round 163
#   round 952 s1 best estimate: fitness 0.0
#   round 848 s1 best estimate: fitness 0.0
#   round 796 s1 best estimate: fitness 0.0
#   round 534 s1 best estimate: fitness 0.0
# round 899 s2 best estimate: fitness 32806.82745891385 after 100002 iterations (runtime: 136.4650001525879s, avg s2 runtime: 25.501000022888185s)
# Starting round 900
#   round 587 s1 best estimate: fitness 0.0
#   round 4 s1 best estimate: fitness 0.0
#   round 692 s1 best estimate: fitness 0.0
#   round 744 s1 best estimate: fitness 0.0
#   round 269 s1 best estimate: fitness 0.0
#   round 481 s1 best estimate: fitness 0.0
# round 321 s2 best estimate: fitness 32920.10160771632 after 100002 iterations (runtime: 137.4170000553131s, avg s2 runtime: 25.725s)
# Starting round 322
#   round 216 s1 best estimate: fitness 3.086494822959059e-29
# round 639 s2 best estimate: fitness 32981.04133964446 after 100002 iterations (runtime: 144.2699999809265s, avg s2 runtime: 27.469000005722044s)
# Starting round 640
#   round 375 s1 best estimate: fitness 0.0
#   round 428 s1 best estimate: fitness 0.0
#   round 163 s1 best estimate: fitness 0.0
#   round 900 s1 best estimate: fitness 0.0
#   round 640 s1 best estimate: fitness 3.1031685644996534e-29
#   round 322 s1 best estimate: fitness 0.0
#     improvement in round 55 est. 4: 32896.96408409381 (counter = 100002) < 32896.96754395899 (counter = 100002); (169.14200019836426s total)
#     improvement in round 110 est. 1: 33126.014043534495 (counter = 100002) < Inf (counter = 0); (32.81699991226196s total)
#     improvement in round 848 est. 1: 33036.27860404701 (counter = 100002) < Inf (counter = 0); (31.884000062942505s total)
#     improvement in round 796 est. 1: 32935.32543442344 (counter = 100002) < Inf (counter = 0); (33.70300006866455s total)
#     improvement in round 534 est. 1: 33135.02289088458 (counter = 100002) < Inf (counter = 0); (33.69199991226196s total)
#     improvement in round 952 est. 1: 32876.69647096685 (counter = 100002) < Inf (counter = 0); (34.47999978065491s total)
#     improvement in round 587 est. 1: 32803.91968500876 (counter = 100002) < Inf (counter = 0); (34.32299995422363s total)
#     improvement in round 269 est. 1: 33010.91320726056 (counter = 100002) < Inf (counter = 0); (33.24900007247925s total)
#     improvement in round 744 est. 1: 32828.57193540416 (counter = 100002) < Inf (counter = 0); (33.74300003051758s total)
#     improvement in round 4 est. 1: 32837.84069784821 (counter = 100002) < Inf (counter = 0); (32.097999811172485s total)
#     improvement in round 216 est. 1: 32951.604445006604 (counter = 100002) < Inf (counter = 0); (33.21300005912781s total)
#     improvement in round 375 est. 1: 32855.67258313863 (counter = 100002) < Inf (counter = 0); (32.289000034332275s total)
#     improvement in round 692 est. 1: 32941.580623275084 (counter = 100002) < Inf (counter = 0); (33.72699999809265s total)
#     improvement in round 481 est. 1: 32883.375636138124 (counter = 100002) < Inf (counter = 0); (34.28200006484985s total)
#     improvement in round 428 est. 1: 32960.6529573776 (counter = 100002) < Inf (counter = 0); (33.92400002479553s total)
#     improvement in round 900 est. 1: 32657.59141969075 (counter = 100002) < Inf (counter = 0); (32.3970000743866s total)
#     improvement in round 163 est. 1: 32754.11357067744 (counter = 100002) < Inf (counter = 0); (33.67700004577637s total)
#     improvement in round 640 est. 1: 32776.51279450938 (counter = 100002) < Inf (counter = 0); (30.98799991607666s total)
#     improvement in round 322 est. 1: 33089.95319365603 (counter = 100002) < Inf (counter = 0); (32.43399977684021s total)
# round 55 s2 best estimate: fitness 32896.96408409381 after 100002 iterations (runtime: 195.00999999046326s, avg s2 runtime: 37.389400005340576s)
# Starting round 56
#     improvement in round 110 est. 2: 33126.01102775965 (counter = 100002) < 33126.014043534495 (counter = 100002); (58.90000009536743s total)
#     improvement in round 952 est. 2: 32876.66102219114 (counter = 100002) < 32876.69647096685 (counter = 100002); (62.93499994277954s total)
#   round 56 s1 best estimate: fitness 0.0
#     improvement in round 4 est. 2: 32837.83877369998 (counter = 100002) < 32837.84069784821 (counter = 100002); (59.88699984550476s total)
#     improvement in round 692 est. 2: 32940.167319796565 (counter = 100002) < 32941.580623275084 (counter = 100002); (61.681999921798706s total)
#     improvement in round 216 est. 2: 32951.35472667144 (counter = 100002) < 32951.604445006604 (counter = 100002); (61.944000005722046s total)
#     improvement in round 481 est. 2: 32883.1951509303 (counter = 100002) < 32883.375636138124 (counter = 100002); (62.700000047683716s total)
#     improvement in round 428 est. 2: 32960.5420805127 (counter = 100002) < 32960.6529573776 (counter = 100002); (63.126999855041504s total)
#     improvement in round 163 est. 2: 32754.092586361916 (counter = 100002) < 32754.11357067744 (counter = 100002); (63.330000162124634s total)
#     improvement in round 640 est. 2: 32776.411361683575 (counter = 100002) < 32776.51279450938 (counter = 100002); (61.526000022888184s total)
#     improvement in round 110 est. 3: 33125.97423510671 (counter = 100002) < 33126.01102775965 (counter = 100002); (89.20600008964539s total)
#     improvement in round 534 est. 3: 33135.019692220994 (counter = 100002) < 33135.02289088458 (counter = 100002); (90.88700008392334s total)
#     improvement in round 796 est. 3: 32935.265694060115 (counter = 100002) < 32935.32543442344 (counter = 100002); (91.7279999256134s total)
#     improvement in round 56 est. 1: 32990.077163083966 (counter = 100002) < Inf (counter = 0); (38.31000018119812s total)
#     improvement in round 4 est. 3: 32837.83756668631 (counter = 100002) < 32837.83877369998 (counter = 100002); (90.41599988937378s total)
#     improvement in round 900 est. 3: 32657.43066490725 (counter = 100002) < 32657.59141969075 (counter = 100002); (92.12800002098083s total)
#     improvement in round 796 est. 4: 32935.2606662004 (counter = 100002) < 32935.265694060115 (counter = 100002); (116.50500011444092s total)
#     improvement in round 375 est. 4: 32855.64805025605 (counter = 100002) < 32855.67258313863 (counter = 100002); (112.88599991798401s total)
#     improvement in round 216 est. 4: 32951.31294115887 (counter = 100002) < 32951.35472667144 (counter = 100002); (115.35500001907349s total)
#     improvement in round 428 est. 4: 32960.521349697294 (counter = 100002) < 32960.5420805127 (counter = 100002); (116.2039999961853s total)
#     improvement in round 163 est. 4: 32754.090340025592 (counter = 100002) < 32754.092586361916 (counter = 100002); (115.98699998855591s total)
#     improvement in round 110 est. 5: 33125.97157636727 (counter = 100002) < 33125.97423510671 (counter = 100002); (139.82500004768372s total)
# round 110 s2 best estimate: fitness 33125.97157636727 after 100002 iterations (runtime: 139.82500004768372s, avg s2 runtime: 26.83699998855591s)
# Starting round 111
# round 534 s2 best estimate: fitness 33135.019692220994 after 100002 iterations (runtime: 138.89299988746643s, avg s2 runtime: 26.076599979400633s)
# Starting round 535
#   round 535 s1 best estimate: fitness 0.0
# round 796 s2 best estimate: fitness 32935.2606662004 after 100002 iterations (runtime: 140.30999994277954s, avg s2 runtime: 26.338399982452394s)
# Starting round 797
#     improvement in round 56 est. 3: 32989.452287615095 (counter = 100002) < 32990.077163083966 (counter = 100002); (85.69800019264221s total)
# round 848 s2 best estimate: fitness 33036.27860404701 after 100002 iterations (runtime: 140.04500007629395s, avg s2 runtime: 26.649399995803833s)
# Starting round 849
# round 375 s2 best estimate: fitness 32855.64805025605 after 100002 iterations (runtime: 137.32299995422363s, avg s2 runtime: 25.7731999874115s)
# Starting round 376
# round 744 s2 best estimate: fitness 32828.57193540416 after 100002 iterations (runtime: 139.3989999294281s, avg s2 runtime: 26.1521999835968s)
# Starting round 745
#     improvement in round 216 est. 5: 32951.05157006118 (counter = 100002) < 32951.31294115887 (counter = 100002); (138.7480001449585s total)
# round 216 s2 best estimate: fitness 32951.05157006118 after 100002 iterations (runtime: 138.7480001449585s, avg s2 runtime: 25.951999998092653s)
# Starting round 217
# round 952 s2 best estimate: fitness 32876.66102219114 after 100002 iterations (runtime: 143.22299981117249s, avg s2 runtime: 26.914599990844728s)
# Starting round 953
# round 692 s2 best estimate: fitness 32940.167319796565 after 100002 iterations (runtime: 140.38899993896484s, avg s2 runtime: 26.498999977111815s)
# Starting round 693
# round 587 s2 best estimate: fitness 32803.91968500876 after 100002 iterations (runtime: 143.6619999408722s, avg s2 runtime: 26.979199981689455s)
# Starting round 588
# round 481 s2 best estimate: fitness 32883.1951509303 after 100002 iterations (runtime: 141.26500010490417s, avg s2 runtime: 26.525s)
# Starting round 482
# round 269 s2 best estimate: fitness 33010.91320726056 after 100002 iterations (runtime: 142.02699995040894s, avg s2 runtime: 26.654400014877318s)
# Starting round 270
#   round 111 s1 best estimate: fitness 0.0
# round 4 s2 best estimate: fitness 32837.83756668631 after 100002 iterations (runtime: 140.80799984931946s, avg s2 runtime: 26.84079999923706s)
# Starting round 5
#     improvement in round 428 est. 5: 32960.41910640349 (counter = 100002) < 32960.521349697294 (counter = 100002); (140.06500005722046s total)
# round 428 s2 best estimate: fitness 32960.41910640349 after 100002 iterations (runtime: 140.06500005722046s, avg s2 runtime: 26.339200019836426s)
# Starting round 429
#   round 849 s1 best estimate: fitness 3.0736497196530455e-29
#   round 797 s1 best estimate: fitness 0.0
#   round 376 s1 best estimate: fitness 0.0
#     improvement in round 900 est. 5: 32657.113453289574 (counter = 100002) < 32657.43066490725 (counter = 100002); (139.92799997329712s total)
# round 900 s2 best estimate: fitness 32657.113453289574 after 100002 iterations (runtime: 139.92799997329712s, avg s2 runtime: 26.366400003433228s)
# Starting round 901
# round 163 s2 best estimate: fitness 32754.090340025592 after 100002 iterations (runtime: 141.41200017929077s, avg s2 runtime: 26.59220004081726s)
# Starting round 164
#   round 953 s1 best estimate: fitness 0.0
#   round 745 s1 best estimate: fitness 0.0
#   round 217 s1 best estimate: fitness 0.0
#   round 693 s1 best estimate: fitness 0.0
#   round 429 s1 best estimate: fitness 0.0
#   round 588 s1 best estimate: fitness 0.0
#   round 270 s1 best estimate: fitness 0.0
# round 322 s2 best estimate: fitness 33089.95319365603 after 100002 iterations (runtime: 141.69999980926514s, avg s2 runtime: 26.801399993896485s)
# Starting round 323
#   round 5 s1 best estimate: fitness 0.0
#   round 482 s1 best estimate: fitness 3.088338607202164e-29
# round 640 s2 best estimate: fitness 32776.411361683575 after 100002 iterations (runtime: 141.15199995040894s, avg s2 runtime: 27.09159998893738s)
# Starting round 641
#   round 901 s1 best estimate: fitness 0.0
#   round 641 s1 best estimate: fitness 0.0
#   round 323 s1 best estimate: fitness 0.0
#   round 164 s1 best estimate: fitness 3.10876658355768e-29
#     improvement in round 535 est. 1: 32960.41277573854 (counter = 100002) < Inf (counter = 0); (26.419000148773193s total)
#     improvement in round 111 est. 1: 33065.288876710714 (counter = 100002) < Inf (counter = 0); (32.430999994277954s total)
#     improvement in round 849 est. 1: 32895.793108855934 (counter = 100002) < Inf (counter = 0); (30.02900004386902s total)
#     improvement in round 797 est. 1: 32902.08843886567 (counter = 100002) < Inf (counter = 0); (31.516000032424927s total)
#     improvement in round 376 est. 1: 33137.611163607835 (counter = 100002) < Inf (counter = 0); (30.124000072479248s total)
#     improvement in round 745 est. 1: 33137.120159274615 (counter = 100002) < Inf (counter = 0); (31.371999979019165s total)
#     improvement in round 953 est. 1: 33032.2272291371 (counter = 100002) < Inf (counter = 0); (32.123000144958496s total)
#     improvement in round 217 est. 1: 32932.09775410612 (counter = 100002) < Inf (counter = 0); (32.39299988746643s total)
#     improvement in round 693 est. 1: 33039.10820651116 (counter = 100002) < Inf (counter = 0); (31.87399983406067s total)
#     improvement in round 5 est. 1: 32903.832107937764 (counter = 100002) < Inf (counter = 0); (30.725000143051147s total)
#     improvement in round 270 est. 1: 33041.97537172136 (counter = 100002) < Inf (counter = 0); (31.361000061035156s total)
#     improvement in round 429 est. 1: 32995.29811909469 (counter = 100002) < Inf (counter = 0); (31.611999988555908s total)
#     improvement in round 482 est. 1: 32850.94873856437 (counter = 100002) < Inf (counter = 0); (32.906999826431274s total)
#     improvement in round 641 est. 1: 32780.23063642645 (counter = 100002) < Inf (counter = 0); (23.73900008201599s total)
#     improvement in round 901 est. 1: 32912.40958466481 (counter = 100002) < Inf (counter = 0); (29.068000078201294s total)
#     improvement in round 588 est. 1: 32903.07288973967 (counter = 100002) < Inf (counter = 0); (33.78200006484985s total)
#     improvement in round 323 est. 1: 32818.446559226664 (counter = 100002) < Inf (counter = 0); (24.64300012588501s total)
#     improvement in round 164 est. 1: 32945.7362602431 (counter = 100002) < Inf (counter = 0); (30.150999784469604s total)
# round 56 s2 best estimate: fitness 32989.452287615095 after 100002 iterations (runtime: 133.92300009727478s, avg s2 runtime: 24.78600001335144s)
# Starting round 57
#     improvement in round 535 est. 2: 32960.282300121755 (counter = 100002) < 32960.41277573854 (counter = 100002); (49.97100019454956s total)
#     improvement in round 111 est. 2: 33065.28333470615 (counter = 100002) < 33065.288876710714 (counter = 100002); (55.50099992752075s total)
#   round 57 s1 best estimate: fitness 0.0
#     improvement in round 953 est. 2: 33032.105317736285 (counter = 100002) < 33032.2272291371 (counter = 100002); (55.0460000038147s total)
#     improvement in round 693 est. 2: 33039.10430338937 (counter = 100002) < 33039.10820651116 (counter = 100002); (54.97000002861023s total)
#     improvement in round 429 est. 2: 32995.274689667756 (counter = 100002) < 32995.29811909469 (counter = 100002); (55.10599994659424s total)
#     improvement in round 588 est. 2: 32903.06206257155 (counter = 100002) < 32903.07288973967 (counter = 100002); (57.6949999332428s total)
#     improvement in round 901 est. 2: 32912.35652185202 (counter = 100002) < 32912.40958466481 (counter = 100002); (53.27800011634827s total)
#     improvement in round 535 est. 3: 32960.21986771175 (counter = 100002) < 32960.282300121755 (counter = 100002); (74.21500015258789s total)
#     improvement in round 376 est. 3: 33136.86811400502 (counter = 100002) < 33137.611163607835 (counter = 100002); (78.87999987602234s total)
#     improvement in round 57 est. 1: 32926.79499579907 (counter = 100002) < Inf (counter = 0); (32.93500018119812s total)
#     improvement in round 217 est. 3: 32931.83404278042 (counter = 100002) < 32932.09775410612 (counter = 100002); (81.29499983787537s total)
#     improvement in round 164 est. 3: 32945.7343721893 (counter = 100002) < 32945.7362602431 (counter = 100002); (79.03699994087219s total)
#     improvement in round 376 est. 4: 33136.82975445219 (counter = 100002) < 33136.86811400502 (counter = 100002); (109.73300004005432s total)
#     improvement in round 849 est. 4: 32895.658377860294 (counter = 100002) < 32895.793108855934 (counter = 100002); (110.26000022888184s total)
#     improvement in round 57 est. 2: 32926.77012009141 (counter = 100002) < 32926.79499579907 (counter = 100002); (63.70800018310547s total)
#     improvement in round 217 est. 4: 32931.82491773371 (counter = 100002) < 32931.83404278042 (counter = 100002); (114.60500001907349s total)
#     improvement in round 5 est. 4: 32903.831827561626 (counter = 100002) < 32903.832107937764 (counter = 100002); (113.90900015830994s total)
#     improvement in round 482 est. 4: 32850.943574397206 (counter = 100002) < 32850.94873856437 (counter = 100002); (117.85899996757507s total)
#     improvement in round 535 est. 5: 32960.19455750372 (counter = 100002) < 32960.21986771175 (counter = 100002); (142.9539999961853s total)
# round 535 s2 best estimate: fitness 32960.19455750372 after 100002 iterations (runtime: 142.95900011062622s, avg s2 runtime: 28.47960000038147s)
# Starting round 536
# round 111 s2 best estimate: fitness 33065.28333470615 after 100002 iterations (runtime: 152.22000002861023s, avg s2 runtime: 28.930999994277954s)
# Starting round 112
#   round 536 s1 best estimate: fitness 0.0
# round 849 s2 best estimate: fitness 32895.658377860294 after 100002 iterations (runtime: 150.65400004386902s, avg s2 runtime: 28.933999967575073s)
# Starting round 850
# round 376 s2 best estimate: fitness 33136.82975445219 after 100002 iterations (runtime: 150.98600006103516s, avg s2 runtime: 28.953999996185303s)
# Starting round 377
# round 797 s2 best estimate: fitness 32902.08843886567 after 100002 iterations (runtime: 153.23600006103516s, avg s2 runtime: 29.10939998626709s)
# Starting round 798
# round 217 s2 best estimate: fitness 32931.82491773371 after 100002 iterations (runtime: 153.28799986839294s, avg s2 runtime: 28.892199993133545s)
# Starting round 218
# round 953 s2 best estimate: fitness 33032.105317736285 after 100002 iterations (runtime: 153.52900004386902s, avg s2 runtime: 29.081199979782106s)
# Starting round 954
# round 745 s2 best estimate: fitness 33137.120159274615 after 100002 iterations (runtime: 154.00800013542175s, avg s2 runtime: 29.077800035476685s)
# Starting round 746
# round 693 s2 best estimate: fitness 33039.10430338937 after 100002 iterations (runtime: 153.5149998664856s, avg s2 runtime: 29.065000009536742s)
# Starting round 694
#     improvement in round 5 est. 5: 32903.83171594129 (counter = 100002) < 32903.831827561626 (counter = 100002); (152.07100009918213s total)
# round 5 s2 best estimate: fitness 32903.83171594129 after 100002 iterations (runtime: 152.07100009918213s, avg s2 runtime: 28.74559998512268s)
# Starting round 6
#   round 112 s1 best estimate: fitness 0.0
#     improvement in round 482 est. 5: 32850.94339870206 (counter = 100002) < 32850.943574397206 (counter = 100002); (154.52099990844727s total)
# round 482 s2 best estimate: fitness 32850.94339870206 after 100002 iterations (runtime: 154.52099990844727s, avg s2 runtime: 29.046000003814697s)
# Starting round 483
#   round 377 s1 best estimate: fitness 0.0
#   round 798 s1 best estimate: fitness 0.0
#     improvement in round 901 est. 5: 32912.23845787327 (counter = 100002) < 32912.35652185202 (counter = 100002); (151.7369999885559s total)
# round 901 s2 best estimate: fitness 32912.23845787327 after 100002 iterations (runtime: 151.7369999885559s, avg s2 runtime: 29.16199998855591s)
# Starting round 902
# round 588 s2 best estimate: fitness 32903.06206257155 after 100002 iterations (runtime: 156.2279999256134s, avg s2 runtime: 29.617599964141846s)
# Starting round 589
#   round 850 s1 best estimate: fitness 0.0
#     improvement in round 270 est. 5: 33041.945412845125 (counter = 100002) < 33041.97537172136 (counter = 100002); (156.4100000858307s total)
# round 270 s2 best estimate: fitness 33041.945412845125 after 100002 iterations (runtime: 156.4170000553131s, avg s2 runtime: 29.665999984741212s)
# Starting round 271
#     improvement in round 641 est. 5: 32780.213486203545 (counter = 100002) < 32780.23063642645 (counter = 100002); (147.73800015449524s total)
# round 641 s2 best estimate: fitness 32780.213486203545 after 100002 iterations (runtime: 147.74700021743774s, avg s2 runtime: 29.367000007629393s)
# Starting round 642
# round 323 s2 best estimate: fitness 32818.446559226664 after 100002 iterations (runtime: 148.18600010871887s, avg s2 runtime: 29.378000020980835s)
# Starting round 324
# round 164 s2 best estimate: fitness 32945.7343721893 after 100002 iterations (runtime: 152.7559998035431s, avg s2 runtime: 29.121399974823s)
# Starting round 165
# round 429 s2 best estimate: fitness 32995.274689667756 after 100002 iterations (runtime: 158.67799997329712s, avg s2 runtime: 30.36360001564026s)
# Starting round 430
#   round 746 s1 best estimate: fitness 0.0
#   round 694 s1 best estimate: fitness 0.0
#   round 218 s1 best estimate: fitness 0.0
#   round 430 s1 best estimate: fitness 0.0
#   round 6 s1 best estimate: fitness 0.0
#   round 954 s1 best estimate: fitness 0.0
#   round 483 s1 best estimate: fitness 0.0
#   round 589 s1 best estimate: fitness 0.0
#   round 902 s1 best estimate: fitness 0.0
#   round 271 s1 best estimate: fitness 0.0
#   round 642 s1 best estimate: fitness 0.0
#   round 324 s1 best estimate: fitness 3.079141648872199e-29
#   round 165 s1 best estimate: fitness 0.0
# ...
#     improvement in round 1000 est. 4: 32689.07818507648 (counter = 100002) < 32689.107802097104 (counter = 100002); (127.89599990844727s total)
#   round 264 s1 best estimate: fitness 0.0
#     improvement in round 370 est. 4: 32907.57010540045 (counter = 100002) < 32907.58992472726 (counter = 100002); (125.84400010108948s total)
# round 634 s2 best estimate: fitness 32938.00365548606 after 100002 iterations (runtime: 144.79500007629395s, avg s2 runtime: 28.70920000076294s)
# Starting round 635
#     improvement in round 317 est. 3: 32995.0080560168 (counter = 100002) < 32995.4420092756 (counter = 100002); (100.75999999046326s total)
#     improvement in round 842 est. 2: 33048.97849939908 (counter = 100002) < 33049.18581315582 (counter = 100002); (67.71799993515015s total)
#     improvement in round 211 est. 4: 33036.02583546757 (counter = 100002) < 33036.06068755507 (counter = 100002); (125.83899998664856s total)
# round 421 s2 best estimate: fitness 33024.93692259537 after 100002 iterations (runtime: 150.8420000076294s, avg s2 runtime: 29.130000019073485s)
# Starting round 422
#   round 635 s1 best estimate: fitness 3.0590998984949243e-29
#   round 422 s1 best estimate: fitness 0.0
#     improvement in round 792 est. 2: 32921.43973737607 (counter = 100002) < 32921.62943689202 (counter = 100002); (64.0849997997284s total)
# round 51 s2 best estimate: fitness 32767.490770260687 after 100002 iterations (runtime: 150.2739999294281s, avg s2 runtime: 28.640399980545045s)
# Starting round 52
#     improvement in round 104 est. 2: 32775.937505593014 (counter = 100002) < 32775.9698588703 (counter = 100002); (61.980000019073486s total)
#     improvement in round 740 est. 2: 32695.198029062314 (counter = 100002) < 32695.402641735203 (counter = 100002); (61.46900010108948s total)
# round 1000 s2 best estimate: fitness 32689.07818507648 after 100002 iterations (runtime: 150.7849998474121s, avg s2 runtime: 28.669999980926512s)
#   round 52 s1 best estimate: fitness 0.0
# round 687 s2 best estimate: fitness 32862.711990757336 after 100002 iterations (runtime: 152.5550000667572s, avg s2 runtime: 29.07200002670288s)
# Starting round 688
#     improvement in round 264 est. 1: 32955.43741827065 (counter = 100002) < Inf (counter = 0); (30.246999979019165s total)
# round 370 s2 best estimate: fitness 32907.57010540045 after 100002 iterations (runtime: 149.48300004005432s, avg s2 runtime: 28.481999969482423s)
# Starting round 371
#     improvement in round 317 est. 4: 32994.992690410894 (counter = 100002) < 32995.0080560168 (counter = 100002); (123.81799983978271s total)
# round 211 s2 best estimate: fitness 33036.02583546757 after 100002 iterations (runtime: 148.13299989700317s, avg s2 runtime: 28.28899998664856s)
# Starting round 212
#     improvement in round 582 est. 4: 32887.30004760337 (counter = 100002) < 32887.32503229932 (counter = 100002); (119.51599979400635s total)
#   round 688 s1 best estimate: fitness 0.0
# round 528 s2 best estimate: fitness 32853.298106167604 after 100002 iterations (runtime: 144.61500000953674s, avg s2 runtime: 27.882200002670288s)
# Starting round 529
#   round 371 s1 best estimate: fitness 0.0
#     improvement in round 157 est. 3: 33166.74270596533 (counter = 100002) < 33167.14114932713 (counter = 100002); (86.20000004768372s total)
#     improvement in round 635 est. 1: 32999.685804152425 (counter = 100002) < Inf (counter = 0); (30.430999994277954s total)
#   round 212 s1 best estimate: fitness 0.0
#   round 529 s1 best estimate: fitness 0.0
#     improvement in round 792 est. 3: 32921.35955579053 (counter = 100002) < 32921.43973737607 (counter = 100002); (87.22999978065491s total)
#     improvement in round 422 est. 1: 33204.59820318105 (counter = 100002) < Inf (counter = 0); (30.868000030517578s total)
#     improvement in round 740 est. 3: 32695.163122772126 (counter = 100002) < 32695.198029062314 (counter = 100002); (84.91400003433228s total)
#     improvement in round 264 est. 2: 32955.386583107625 (counter = 100002) < 32955.43741827065 (counter = 100002); (53.76099991798401s total)
#     improvement in round 52 est. 1: 32846.175240226345 (counter = 100002) < Inf (counter = 0); (32.040000200271606s total)
# round 317 s2 best estimate: fitness 32994.992690410894 after 100002 iterations (runtime: 147.731999874115s, avg s2 runtime: 28.255599975585938s)
# Starting round 318
#     improvement in round 582 est. 5: 32887.29370085085 (counter = 100002) < 32887.30004760337 (counter = 100002); (142.93999981880188s total)
# round 582 s2 best estimate: fitness 32887.29370085085 after 100002 iterations (runtime: 142.93999981880188s, avg s2 runtime: 27.350600004196167s)
# Starting round 583
#     improvement in round 688 est. 1: 32716.537644314045 (counter = 100002) < Inf (counter = 0); (31.44000005722046s total)
#   round 318 s1 best estimate: fitness 0.0
#     improvement in round 371 est. 1: 32921.56589158953 (counter = 100002) < Inf (counter = 0); (30.677000045776367s total)
#     improvement in round 635 est. 2: 32999.4954612382 (counter = 100002) < 32999.685804152425 (counter = 100002); (53.91700005531311s total)
#     improvement in round 212 est. 1: 32835.218802227435 (counter = 100002) < Inf (counter = 0); (30.966000080108643s total)
#   round 583 s1 best estimate: fitness 0.0
#     improvement in round 529 est. 1: 32857.415447897736 (counter = 100002) < Inf (counter = 0); (29.65499997138977s total)
# round 476 s2 best estimate: fitness 32801.38190690596 after 100002 iterations (runtime: 143.22300004959106s, avg s2 runtime: 27.03359999656677s)
# Starting round 477
# round 948 s2 best estimate: fitness 33012.273728071035 after 100002 iterations (runtime: 142.37199997901917s, avg s2 runtime: 26.70420002937317s)
#   round 477 s1 best estimate: fitness 0.0
#     improvement in round 842 est. 5: 33048.93740721143 (counter = 100002) < 33048.97849939908 (counter = 100002); (145.87199997901917s total)
# round 842 s2 best estimate: fitness 33048.93740721143 after 100002 iterations (runtime: 145.87199997901917s, avg s2 runtime: 27.412599992752074s)
# Starting round 843
# round 896 s2 best estimate: fitness 32998.37510746428 after 100002 iterations (runtime: 151.375s, avg s2 runtime: 29.212599992752075s)
#     improvement in round 688 est. 2: 32716.342897454793 (counter = 100002) < 32716.537644314045 (counter = 100002); (61.05399990081787s total)
#     improvement in round 318 est. 1: 32984.853257277624 (counter = 100002) < Inf (counter = 0); (33.944000005722046s total)
# round 157 s2 best estimate: fitness 33166.74270596533 after 100002 iterations (runtime: 137.92400002479553s, avg s2 runtime: 25.79539999961853s)
# Starting round 158
#   round 843 s1 best estimate: fitness 0.0
#     improvement in round 583 est. 1: 32948.75937234396 (counter = 100002) < Inf (counter = 0); (39.51600003242493s total)
#     improvement in round 212 est. 2: 32833.717552163136 (counter = 100002) < 32835.218802227435 (counter = 100002); (64.56299996376038s total)
#   round 158 s1 best estimate: fitness 0.0
#     improvement in round 529 est. 2: 32857.06962473602 (counter = 100002) < 32857.415447897736 (counter = 100002); (62.78699994087219s total)
# round 792 s2 best estimate: fitness 32921.35955579053 after 100002 iterations (runtime: 145.93499994277954s, avg s2 runtime: 28.12400002479553s)
#     improvement in round 104 est. 5: 32775.93084044223 (counter = 100002) < 32775.937505593014 (counter = 100002); (154.49000000953674s total)
# round 104 s2 best estimate: fitness 32775.93084044223 after 100002 iterations (runtime: 154.49000000953674s, avg s2 runtime: 29.311999988555907s)
# Starting round 105
# round 740 s2 best estimate: fitness 32695.163122772126 after 100002 iterations (runtime: 151.28099989891052s, avg s2 runtime: 28.731999969482423s)
#     improvement in round 477 est. 1: 32936.21055918615 (counter = 100002) < Inf (counter = 0); (50.18300008773804s total)
#     improvement in round 52 est. 3: 32846.113693543615 (counter = 100002) < 32846.175240226345 (counter = 100002); (98.10400009155273s total)
#   round 105 s1 best estimate: fitness 0.0
#     improvement in round 371 est. 3: 32921.130546844855 (counter = 100002) < 32921.56589158953 (counter = 100002); (99.90000009536743s total)
#     improvement in round 158 est. 1: 33087.214815548024 (counter = 100002) < Inf (counter = 0); (44.0220000743866s total)
#     improvement in round 583 est. 2: 32948.74094528672 (counter = 100002) < 32948.75937234396 (counter = 100002); (78.12099981307983s total)
#     improvement in round 843 est. 1: 33072.6217058619 (counter = 100002) < Inf (counter = 0); (49.908000230789185s total)
#     improvement in round 477 est. 2: 32935.5290198462 (counter = 100002) < 32936.21055918615 (counter = 100002); (77.92000007629395s total)
#     improvement in round 264 est. 5: 32955.37934898845 (counter = 100002) < 32955.386583107625 (counter = 100002); (149.4139997959137s total)
# round 264 s2 best estimate: fitness 32955.37934898845 after 100002 iterations (runtime: 149.4139997959137s, avg s2 runtime: 28.41239995956421s)
# Starting round 265
#     improvement in round 105 est. 1: 32870.98065893432 (counter = 100002) < Inf (counter = 0); (34.32100009918213s total)
#     improvement in round 318 est. 3: 32984.85312911136 (counter = 100002) < 32984.853257277624 (counter = 100002); (98.3510000705719s total)
#   round 265 s1 best estimate: fitness 0.0
# round 635 s2 best estimate: fitness 32999.4954612382 after 100002 iterations (runtime: 148.74000000953674s, avg s2 runtime: 28.225400018692017s)
# Starting round 636
#   round 636 s1 best estimate: fitness 0.0
# round 422 s2 best estimate: fitness 33204.59820318105 after 100002 iterations (runtime: 151.73799991607666s, avg s2 runtime: 29.360799980163574s)
# Starting round 423
# round 52 s2 best estimate: fitness 32846.113693543615 after 100002 iterations (runtime: 148.17400002479553s, avg s2 runtime: 28.328599977493287s)
# Starting round 53
#     improvement in round 105 est. 2: 32870.980584619814 (counter = 100002) < 32870.98065893432 (counter = 100002); (56.3050000667572s total)
#   round 423 s1 best estimate: fitness 0.0
#     improvement in round 318 est. 4: 32984.83840451159 (counter = 100002) < 32984.85312911136 (counter = 100002); (119.92499995231628s total)
# round 688 s2 best estimate: fitness 32716.342897454793 after 100002 iterations (runtime: 148.40499997138977s, avg s2 runtime: 28.363199996948243s)
#   round 53 s1 best estimate: fitness 0.0
# round 371 s2 best estimate: fitness 32921.130546844855 after 100002 iterations (runtime: 146.80700016021729s, avg s2 runtime: 28.067400026321412s)
#     improvement in round 265 est. 1: 32969.860465202 (counter = 100002) < Inf (counter = 0); (29.83300018310547s total)
# round 212 s2 best estimate: fitness 32833.717552163136 after 100002 iterations (runtime: 146.82999992370605s, avg s2 runtime: 27.830800008773803s)
# round 529 s2 best estimate: fitness 32857.06962473602 after 100002 iterations (runtime: 146.71799993515015s, avg s2 runtime: 28.001200008392335s)
# Starting round 530
#     improvement in round 636 est. 1: 32865.05788764553 (counter = 100002) < Inf (counter = 0); (28.055999994277954s total)
#   round 530 s1 best estimate: fitness 0.0
#     improvement in round 477 est. 4: 32935.46506757594 (counter = 100002) < 32935.5290198462 (counter = 100002); (122.96099996566772s total)
#     improvement in round 105 est. 3: 32870.98044895304 (counter = 100002) < 32870.980584619814 (counter = 100002); (80.25399994850159s total)
# round 318 s2 best estimate: fitness 32984.83840451159 after 100002 iterations (runtime: 139.94700002670288s, avg s2 runtime: 27.003800010681154s)
#     improvement in round 423 est. 1: 33036.54269141683 (counter = 100002) < Inf (counter = 0); (29.27500009536743s total)
#     improvement in round 53 est. 1: 33104.25161461271 (counter = 100002) < Inf (counter = 0); (29.16100001335144s total)
# round 583 s2 best estimate: fitness 32948.74094528672 after 100002 iterations (runtime: 143.52600002288818s, avg s2 runtime: 27.3768000125885s)
#     improvement in round 843 est. 4: 33072.62033699418 (counter = 100002) < 33072.6217058619 (counter = 100002); (117.2480001449585s total)
#     improvement in round 530 est. 1: 32799.31550274876 (counter = 100002) < Inf (counter = 0); (27.57799983024597s total)
#     improvement in round 477 est. 5: 32935.31662656895 (counter = 100002) < 32935.46506757594 (counter = 100002); (144.3069999217987s total)
# round 477 s2 best estimate: fitness 32935.31662656895 after 100002 iterations (runtime: 144.3069999217987s, avg s2 runtime: 27.3981999874115s)
# round 158 s2 best estimate: fitness 33087.214815548024 after 100002 iterations (runtime: 126.16199994087219s, avg s2 runtime: 23.56159996986389s)
# Starting round 159
#     improvement in round 423 est. 2: 33036.52961685591 (counter = 100002) < 33036.54269141683 (counter = 100002); (50.00100016593933s total)
#   round 159 s1 best estimate: fitness 0.0
#     improvement in round 265 est. 3: 32969.3265910702 (counter = 100002) < 32969.860465202 (counter = 100002); (73.91100001335144s total)
# round 843 s2 best estimate: fitness 33072.62033699418 after 100002 iterations (runtime: 135.89900016784668s, avg s2 runtime: 25.182800006866454s)
# Starting round 844
#     improvement in round 636 est. 3: 32864.9352913508 (counter = 100002) < 32865.05788764553 (counter = 100002); (67.62199997901917s total)
#   round 844 s1 best estimate: fitness 0.0
# round 105 s2 best estimate: fitness 32870.98044895304 after 100002 iterations (runtime: 121.63800001144409s, avg s2 runtime: 22.657000017166137s)
# Starting round 106
#     improvement in round 159 est. 1: 32861.70370270406 (counter = 100002) < Inf (counter = 0); (21.136000156402588s total)
#     improvement in round 265 est. 4: 32969.31072481943 (counter = 100002) < 32969.3265910702 (counter = 100002); (93.43200016021729s total)
#   round 106 s1 best estimate: fitness 0.0
#     improvement in round 844 est. 1: 33045.201213598055 (counter = 100002) < Inf (counter = 0); (21.657000064849854s total)
#     improvement in round 106 est. 1: 32969.81423510449 (counter = 100002) < Inf (counter = 0); (23.81599998474121s total)
# round 636 s2 best estimate: fitness 32864.9352913508 after 100002 iterations (runtime: 103.56100010871887s, avg s2 runtime: 19.472399997711182s)
# round 265 s2 best estimate: fitness 32969.31072481943 after 100002 iterations (runtime: 112.7110002040863s, avg s2 runtime: 21.23300004005432s)
# round 423 s2 best estimate: fitness 33036.52961685591 after 100002 iterations (runtime: 103.6930000782013s, avg s2 runtime: 19.340399980545044s)
# Starting round 424
#   round 424 s1 best estimate: fitness 0.0
#     improvement in round 844 est. 3: 33045.13162002685 (counter = 100002) < 33045.201213598055 (counter = 100002); (52.25399994850159s total)
#     improvement in round 530 est. 5: 32799.3045067212 (counter = 100002) < 32799.31550274876 (counter = 100002); (98.05599999427795s total)
# round 530 s2 best estimate: fitness 32799.3045067212 after 100002 iterations (runtime: 98.05599999427795s, avg s2 runtime: 18.333200025558472s)
# round 53 s2 best estimate: fitness 33104.25161461271 after 100002 iterations (runtime: 111.98600006103516s, avg s2 runtime: 20.98159999847412s)
#     improvement in round 424 est. 1: 32775.23598838171 (counter = 100002) < Inf (counter = 0); (21.257999897003174s total)
# round 159 s2 best estimate: fitness 32861.70370270406 after 100002 iterations (runtime: 81.45500016212463s, avg s2 runtime: 15.44520001411438s)
# round 844 s2 best estimate: fitness 33045.13162002685 after 100002 iterations (runtime: 79.49799990653992s, avg s2 runtime: 14.938399982452392s)
#     improvement in round 424 est. 2: 32775.03496046135 (counter = 100002) < 32775.23598838171 (counter = 100002); (34.14100003242493s total)
# round 106 s2 best estimate: fitness 32969.81423510449 after 100002 iterations (runtime: 79.30099987983704s, avg s2 runtime: 14.777199983596802s)
#     improvement in round 424 est. 4: 32775.03479839546 (counter = 100002) < 32775.03496046135 (counter = 100002); (53.7039999961853s total)
# round 424 s2 best estimate: fitness 32775.03479839546 after 100002 iterations (runtime: 62.276000022888184s, avg s2 runtime: 11.528399991989136s)
